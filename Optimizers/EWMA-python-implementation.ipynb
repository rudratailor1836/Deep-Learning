# %%
import pandas as pd 
import numpy as np 

import matplotlib.pyplot as plt 

df = pd.read_csv('DailyDelhiClimate.csv')
df.head()
# Out:
#          date   meantemp   humidity  wind_speed  meanpressure
# 0  2013-01-01  10.000000  84.500000    0.000000   1015.666667
# 1  2013-01-02   7.400000  92.000000    2.980000   1017.800000
# 2  2013-01-03   7.166667  87.000000    4.633333   1018.666667
# 3  2013-01-04   8.666667  71.333333    1.233333   1017.166667
# 4  2013-01-05   6.000000  86.833333    3.700000   1016.500000

# %%
df = df[['date', 'meantemp']]
df = df.iloc[:250,:]

# %%
plt.scatter(df['date'],df['meantemp'],color='red')

# %%
x1 = df['meantemp'].ewm(alpha=0.1).mean() #Alpha = (1-B)
x1
# Out:
# 0      10.000000
# 1       8.631579
# 2       8.091021
# 3       8.258408
# 4       7.706918
#          ...
# 245    30.323458
# 246    30.462541
# 247    30.582954
# 248    30.581801
# 249    30.606954
# Name: meantemp, Length: 250, dtype: float64

# %%
df['ewma'] = x1

# %%
df
# Out:
#            date   meantemp       ewma
# 0    2013-01-01  10.000000  10.000000
# 1    2013-01-02   7.400000   8.631579
# 2    2013-01-03   7.166667   8.091021
# 3    2013-01-04   8.666667   8.258408
# 4    2013-01-05   6.000000   7.706918
# ..          ...        ...        ...
# 245  2013-09-03  32.750000  30.323458
# 246  2013-09-04  31.714286  30.462541
# 247  2013-09-05  31.666667  30.582954
# 248  2013-09-06  30.571429  30.581801
# 249  2013-09-07  30.833333  30.606954
#
# [250 rows x 3 columns]

# %%
plt.scatter(df['date'],df['meantemp'],color='red')
plt.plot(df['date'],x1,color='black',label='alpha=0.5')
plt.legend()
plt.show()
