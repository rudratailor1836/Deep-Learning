# %%
import numpy as np 

docs = [
    'go india',
    'india india',
    'jeetega bhai jeetega india jeetega',
    'bharat mmata ki jai',
    'kohli kohli',
    'sachin sachin',
    'dhoni dhoni',
    "I don't support politics",
    "I don't support religion"
]

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
tokenizer = Tokenizer(oov_token='nothing')

# %%
tokenizer.fit_on_texts(docs)

# %%
tokenizer.word_index
# Out:
# {'nothing': 1,
#  'india': 2,
#  'jeetega': 3,
#  'kohli': 4,
#  'sachin': 5,
#  'dhoni': 6,
#  'i': 7,
#  "don't": 8,
#  'support': 9,
#  'go': 10,
#  'bhai': 11,
#  'bharat': 12,
#  'mmata': 13,
#  'ki': 14,
#  'jai': 15,
#  'politics': 16,
#  'religion': 17}

# %%
tokenizer.word_counts
# Out:
# OrderedDict([('go', 1),
#              ('india', 4),
#              ('jeetega', 3),
#              ('bhai', 1),
#              ('bharat', 1),
#              ('mmata', 1),
#              ('ki', 1),
#              ('jai', 1),
#              ('kohli', 2),
#              ('sachin', 2),
#              ('dhoni', 2),
#              ('i', 2),
#              ("don't", 2),
#              ('support', 2),
#              ('politics', 1),
#              ('religion', 1)])

# %%
tokenizer.document_count
# Out:
# 9

# %%
sequences = tokenizer.texts_to_sequences(docs)

# %%
sequences
# Out:
# [[10, 2],
#  [2, 2],
#  [3, 11, 3, 2, 3],
#  [12, 13, 14, 15],
#  [4, 4],
#  [5, 5],
#  [6, 6],
#  [7, 8, 9, 16],
#  [7, 8, 9, 17]]

# %%
# Padding Apply
from keras.utils import pad_sequences

# %%
sequences = pad_sequences(sequences,padding='post')

# %%
sequences
# Out:
# array([[10,  2,  0,  0,  0],
#        [ 2,  2,  0,  0,  0],
#        [ 3, 11,  3,  2,  3],
#        [12, 13, 14, 15,  0],
#        [ 4,  4,  0,  0,  0],
#        [ 5,  5,  0,  0,  0],
#        [ 6,  6,  0,  0,  0],
#        [ 7,  8,  9, 16,  0],
#        [ 7,  8,  9, 17,  0]], dtype=int32)

# %%
from keras.models import Sequential 
from keras.layers import Embedding ,Dense

model = Sequential()


model.add(Embedding(17,output_dim=2, input_length=5))
model.add(Dense(1))

model.summary()
# Out:
# c:\Users\rudra\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\layers\core\embedding.py:103: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_5 (Embedding)         │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile('adam','accuracy')
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.

# %%
pred = model.predict(sequences)
print(pred)
# Out:
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 pred = model.predict(sequences)
#       2 print(pred)
#
# File c:\Users\rudra\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\utils\traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File c:\Users\rudra\AppData\Local\Programs\Python\Python313\Lib\site-packages\tensorflow\python\eager\execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# InvalidArgumentError: Graph execution error:
#
# Detected at node sequential_5_1/embedding_5_1/GatherV2 defined at (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#
#   File "<frozen runpy>", line 88, in _run_code
#
#   File "C:\Users\rudra\AppData\Roaming\Python\Python313\site-packages\ipykernel_launcher.py", line 18, in <module>
#
#   File "C:\Users\rudra\AppData\Roaming\Python\Python313\site-packages\traitlets\config\application.py", line 1082, in launch_instance
#
#   File "C:\Users\rudra\AppData\Roaming\Python\Python313\site-packages\ipykernel\kernelapp.py", line 758, in start
#
#   File "C:\Users\rudra\AppData\Roaming\Python\Python313\site-packages\tornado\platform\asyncio.py", line 211, in start
#
#   File "c:\Users\rudra\AppData\Local\Programs\Python\Python313\Lib\asyncio\base_events.py", line 679, in run_forever
#
#   File "c:\Users\rudra\AppData\Local\Programs\Python\Python313\Lib\asyncio\base_events.py", line 2027, in _run_once
#
#   File "c:\Users\rudra\AppData\Local\Programs\Python\Python313\Lib\asyncio\events.py", line 89, in _run
#
#   File "C:\Users\rudra\AppData\Roaming\Python\Python313\site-packages\ipykernel\kernelbase.py", line 621, in shell_main
#
#   File "C:\Users\rudra\AppData\Roaming\Python\Python313\site-packages\ipykernel\kernelbase.py", line 478, in dispatch_shell
#
#   File "C:\Users\rudra\AppData\Roaming\Python\Python313\site-packages\ipykernel\ipkernel.py", line 372, in execute_request
#
#   File "C:\Users\rudra\AppData\Roaming\Python\Python313\site-packages\ipykernel\kernelbase.py", line 834, in execute_request
#
#   File "C:\Users\rudra\AppData\Roaming\Python\Python313\site-packages\ipykernel\ipkernel.py", line 464, in do_execute
#
#   File "C:\Users\rudra\AppData\Roaming\Python\Python313\site-packages\ipykernel\zmqshell.py", line 663, in run_cell
#
#   File "C:\Users\rudra\AppData\Roaming\Python\Python313\site-packages\IPython\core\interactiveshell.py", line 3170, in run_cell
#
#   File "C:\Users\rudra\AppData\Roaming\Python\Python313\site-packages\IPython\core\interactiveshell.py", line 3225, in _run_cell
#
#   File "C:\Users\rudra\AppData\Roaming\Python\Python313\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#
#   File "C:\Users\rudra\AppData\Roaming\Python\Python313\site-packages\IPython\core\interactiveshell.py", line 3447, in run_cell_async
#
#   File "C:\Users\rudra\AppData\Roaming\Python\Python313\site-packages\IPython\core\interactiveshell.py", line 3688, in run_ast_nodes
#
#   File "C:\Users\rudra\AppData\Roaming\Python\Python313\site-packages\IPython\core\interactiveshell.py", line 3748, in run_code
#
#   File "C:\Users\rudra\AppData\Local\Temp\ipykernel_20484\2269839758.py", line 1, in <module>
#
#   File "c:\Users\rudra\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\utils\traceback_utils.py", line 117, in error_handler
#
#   File "c:\Users\rudra\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\backend\tensorflow\trainer.py", line 588, in predict
#
#   File "c:\Users\rudra\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\backend\tensorflow\trainer.py", line 282, in one_step_on_data_distributed
#
#   File "c:\Users\rudra\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\backend\tensorflow\trainer.py", line 125, in wrapper
#
#   File "c:\Users\rudra\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\backend\tensorflow\trainer.py", line 271, in one_step_on_data
#
#   File "c:\Users\rudra\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\backend\tensorflow\trainer.py", line 110, in predict_step
#
#   File "c:\Users\rudra\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\utils\traceback_utils.py", line 117, in error_handler
#
#   File "c:\Users\rudra\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\layers\layer.py", line 998, in __call__
#
#   File "c:\Users\rudra\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\utils\traceback_utils.py", line 117, in error_handler
#
#   File "c:\Users\rudra\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\ops\operation.py", line 59, in __call__
#
#   File "c:\Users\rudra\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\utils\traceback_utils.py", line 156, in error_handler
#
#   File "c:\Users\rudra\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\models\sequential.py", line 239, in call
#
#   File "c:\Users\rudra\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\models\functional.py", line 183, in call
#
#   File "c:\Users\rudra\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\ops\function.py", line 210, in _run_through_graph
#
#   File "c:\Users\rudra\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\models\functional.py", line 706, in call
#
#   File "c:\Users\rudra\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\utils\traceback_utils.py", line 117, in error_handler
#
#   File "c:\Users\rudra\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\layers\layer.py", line 998, in __call__
#
#   File "c:\Users\rudra\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\utils\traceback_utils.py", line 117, in error_handler
#
#   File "c:\Users\rudra\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\ops\operation.py", line 59, in __call__
#
#   File "c:\Users\rudra\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\utils\traceback_utils.py", line 156, in error_handler
#
#   File "c:\Users\rudra\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\layers\core\embedding.py", line 169, in call
#
#   File "c:\Users\rudra\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\ops\numpy.py", line 7613, in take
#
#   File "c:\Users\rudra\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\backend\tensorflow\numpy.py", line 3015, in take
#
# indices[8,3] = 17 is not in [0, 17)
# 	 [[{{node sequential_5_1/embedding_5_1/GatherV2}}]] [Op:__inference_one_step_on_data_distributed_245]
